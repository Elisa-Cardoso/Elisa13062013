# %% [markdown]
# <a href="https://colab.research.google.com/github/ElisaCSouza23/projetos/blob/main/Trabalho_final_Est%C3%A1gio_Cedro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
ibri = pd.read_excel('IRBI Anexo IV_2021.xlsx')
ibri
# Out:
#                CNPJ                                       RAZÃO SOCIAL  \
# 0     07205440/0001                                 AGRICOLA XINGU S/A
# 1     07205440/0001                                 AGRICOLA XINGU S/A
# 2     18531594/0001             SLC-MIT EMPREENDIMENTOS AGRICOLAS S.A.
# 3     89096457/0001                                  SLC AGRICOLA S.A.
# 4     01722958/0001  BOA ESPERANCA AGROPECUARIA LTDA - EM RECUPERAC...
# ...             ...                                                ...
# 9478  17678752/0001                ANTONIO RICARDO MARTINS 63339200106
# 9479  00472409/0001                  PERSONAL COMERCIO E SERVICOS LTDA
# 9480  13452690/0001                          LAV NORTE LAVANDERIA LTDA
# 9481  31095261/0001                 BLINK LAB COSMETICOS E BELEZA LTDA
# 9482  22194870/0001  OLYMPIC BROADCASTING SERVICES, S.L - LEI 12.78...
#
#                           CLASSE CNAE ESTAB IMPDR EXPDR  \
# 0                                    Cultivo de cereais
# ...

# %%
empresas = pd.read_excel('Empresas que geraram creditos.xlsx')
empresas.head()
# Out:
#   Relação de Empresas que geraram crédito de lei de informática  \
# 0                                                NaN
# 1                                             indice
# 2                                                  1
# 3                                                  2
# 4                                                  3
#
#            Unnamed: 1                                         Unnamed: 2
# 0                 NaN                                                NaN
# 1                cnpj                                       razao social
# 2  82.901.000/0022-51  INTELBRAS S.A. INDUSTRIA DE TELECOMUNICACAO EL...
# 3  74.404.229/0010-19          FLEXTRONICS INTERNATIONAL TECNOLOGIA LTDA
# 4  09.811.654/0010-60                             ACUMULADORES MOURA S A

# %%
# Renomeando as colunas do dataframe "empresas"
empresas = empresas.rename(columns={empresas.columns[1]: 'CNPJ', empresas.columns[2]: 'RAZÃO SOCIAL'})
empresas.head()
# Out:
#   Relação de Empresas que geraram crédito de lei de informática  \
# 0                                                NaN
# 1                                             indice
# 2                                                  1
# 3                                                  2
# 4                                                  3
#
#                  CNPJ                                       RAZÃO SOCIAL
# 0                 NaN                                                NaN
# 1                cnpj                                       razao social
# 2  82.901.000/0022-51  INTELBRAS S.A. INDUSTRIA DE TELECOMUNICACAO EL...
# 3  74.404.229/0010-19          FLEXTRONICS INTERNATIONAL TECNOLOGIA LTDA
# 4  09.811.654/0010-60                             ACUMULADORES MOURA S A

# %%
contato_endereço_cnpj = pd.read_excel("contato_endereço_cnpj.xlsx")
contato_endereço_cnpj
# Out:
#                     CNPJ                                           Endereço  \
# 0    55.625.511/0001-90   Rua Tapes, 330 Jardim Aeroporto São Paulo / SP...
# 1    18.668.901/0001-11   ROD JOSE CARLOS DAUX, nº 600, Sala 313 João Pa...
# 2    79.647.087/0001-43   Rua Joe Colaço, 954 SANTA MONICA Florianópolis...
# 3    06.339.167/0001-68   Rua Isaias Regis de Miranda, 146V. HAUER HAUER...
# 4    07.157.915/0001-54    Av. Itabuna, 1880 Centro Ilhéus / BA - 45658565
# ..                   ...                                                ...
# 510  30.767.266/0001-25   RUA GUARANIS, 598 Centro SANTA BARBARA DO OEST...
# 511  81.365.223/0001-54   BR 282, Km 576 Distrito Industrial Leste Pinha...
# 512  90.443.821/0001-95   Rua Henrique Eckhardt, 2187 Centro Lajeado / R...
# 513  06.105.781/0001-65   Rua Padre João Batista Reus, nº 215 Caminho No...
# 514  07.019.511/0001-02   Rua Tenente Francisco Ferreira de Souza, 528 H...
#
#                                                Contato
# ...

# %%
# Selecionando colunas de interesse
colunas_ibri = ['CNPJ', 'RAZÃO SOCIAL', 'VALOR DOS INCENTIVOS, RENÚNCIAS, BENEFÍCIOS OU IMUNIDADES DE IPI']
df_ibri = ibri[colunas_ibri]
df_ibri
# Out:
#                CNPJ                                       RAZÃO SOCIAL  \
# 0     07205440/0001                                 AGRICOLA XINGU S/A
# 1     07205440/0001                                 AGRICOLA XINGU S/A
# 2     18531594/0001             SLC-MIT EMPREENDIMENTOS AGRICOLAS S.A.
# 3     89096457/0001                                  SLC AGRICOLA S.A.
# 4     01722958/0001  BOA ESPERANCA AGROPECUARIA LTDA - EM RECUPERAC...
# ...             ...                                                ...
# 9478  17678752/0001                ANTONIO RICARDO MARTINS 63339200106
# 9479  00472409/0001                  PERSONAL COMERCIO E SERVICOS LTDA
# 9480  13452690/0001                          LAV NORTE LAVANDERIA LTDA
# 9481  31095261/0001                 BLINK LAB COSMETICOS E BELEZA LTDA
# 9482  22194870/0001  OLYMPIC BROADCASTING SERVICES, S.L - LEI 12.78...
#
#      VALOR DOS INCENTIVOS, RENÚNCIAS, BENEFÍCIOS OU IMUNIDADES DE IPI
# ...

# %%
# Selecionando colunas de interesse
colunas_empresas = ['CNPJ', 'RAZÃO SOCIAL']
df_empresas = empresas[colunas_empresas]
df_empresas
# Out:
#                    CNPJ                                       RAZÃO SOCIAL
# 0                   NaN                                                NaN
# 1                  cnpj                                       razao social
# 2    82.901.000/0022-51  INTELBRAS S.A. INDUSTRIA DE TELECOMUNICACAO EL...
# 3    74.404.229/0010-19          FLEXTRONICS INTERNATIONAL TECNOLOGIA LTDA
# 4    09.811.654/0010-60                             ACUMULADORES MOURA S A
# ..                  ...                                                ...
# 379  03.394.691/0001-43               CTRLTECH - CONVERSAO DE ENERGIA S.A.
# 380  07.108.509/0001-00                    SDC ENGENHARIA DE SISTEMAS LTDA
# 381  05.120.418/0001-56                    ELSTER MEDICAO DE ENERGIA LTDA.
# 382  12.147.887/0001-24  ABSOLUT MOBILE DO BRASIL DISTRIBUIDORA DE PROD...
# 383  84.683.556/0001-10           KAVO DO BRASIL INDUSTRIA E COMERCIO LTDA
#
# [384 rows x 2 columns]

# %%
# Selecionando colunas de interesse
colunas_contato_endereço = ['CNPJ', 'Endereço', 'Contato']
df_contato_endereço = contato_endereço_cnpj[colunas_contato_endereço]
df_contato_endereço
# Out:
#                     CNPJ                                           Endereço  \
# 0    55.625.511/0001-90   Rua Tapes, 330 Jardim Aeroporto São Paulo / SP...
# 1    18.668.901/0001-11   ROD JOSE CARLOS DAUX, nº 600, Sala 313 João Pa...
# 2    79.647.087/0001-43   Rua Joe Colaço, 954 SANTA MONICA Florianópolis...
# 3    06.339.167/0001-68   Rua Isaias Regis de Miranda, 146V. HAUER HAUER...
# 4    07.157.915/0001-54    Av. Itabuna, 1880 Centro Ilhéus / BA - 45658565
# ..                   ...                                                ...
# 510  30.767.266/0001-25   RUA GUARANIS, 598 Centro SANTA BARBARA DO OEST...
# 511  81.365.223/0001-54   BR 282, Km 576 Distrito Industrial Leste Pinha...
# 512  90.443.821/0001-95   Rua Henrique Eckhardt, 2187 Centro Lajeado / R...
# 513  06.105.781/0001-65   Rua Padre João Batista Reus, nº 215 Caminho No...
# 514  07.019.511/0001-02   Rua Tenente Francisco Ferreira de Souza, 528 H...
#
#                                                Contato
# ...

# %%
import pandas as pd


# Exemplo de uso
cnpj_sem_pontuacao = "221948700001"
cnpj_com_pontuacao = formatar_cnpj(cnpj_sem_pontuacao)

print(cnpj_com_pontuacao)

# Supondo que as colunas já foram selecionadas como mencionado anteriormente

# Inicializando o DataFrame final com o merge entre 'ibri' e 'empresas'
df_final = pd.merge(df_ibri, df_empresas, on='CNPJ', how='left')

# Removendo a coluna "RAZÃO SOCIAL_y"
df_final = df_final.drop(columns=['RAZÃO SOCIAL_y'])

# Renomeando a coluna "RAZÃO SOCIAL_x" para "RAZÃO SOCIAL"
df_final = df_final.rename(columns={'RAZÃO SOCIAL_x': 'RAZÃO SOCIAL'})

# Convertendo a coluna "VALOR DOS INCENTIVOS, RENÚNCIAS, BENEFÍCIOS OU IMUNIDADES DE IPI" para numérico
df_final['VALOR DOS INCENTIVOS, RENÚNCIAS, BENEFÍCIOS OU IMUNIDADES DE IPI'] = pd.to_numeric(df_final['VALOR DOS INCENTIVOS, RENÚNCIAS, BENEFÍCIOS OU IMUNIDADES DE IPI'], errors='coerce')

# Agrupando por 'CNPJ' e somando os valores de incentivos de IPI para empresas com múltiplos registros
df_final['VALOR DOS INCENTIVOS, RENÚNCIAS, BENEFÍCIOS OU IMUNIDADES DE IPI'] = df_final.groupby('CNPJ')['VALOR DOS INCENTIVOS, RENÚNCIAS, BENEFÍCIOS OU IMUNIDADES DE IPI'].transform('sum')

# Removendo duplicatas
df_final = df_final.drop_duplicates(subset='CNPJ', keep='first')

# Exibindo o DataFrame final

df_final
# Out:
# 00.221.948/7000-01
#                CNPJ                                       RAZÃO SOCIAL  \
# 0     07205440/0001                                 AGRICOLA XINGU S/A
# 2     18531594/0001             SLC-MIT EMPREENDIMENTOS AGRICOLAS S.A.
# 3     89096457/0001                                  SLC AGRICOLA S.A.
# 4     01722958/0001  BOA ESPERANCA AGROPECUARIA LTDA - EM RECUPERAC...
# 5     10425282/0001                           BOM FUTURO AGRICOLA LTDA
# ...             ...                                                ...
# 9478  17678752/0001                ANTONIO RICARDO MARTINS 63339200106
# 9479  00472409/0001                  PERSONAL COMERCIO E SERVICOS LTDA
# 9480  13452690/0001                          LAV NORTE LAVANDERIA LTDA
# 9481  31095261/0001                 BLINK LAB COSMETICOS E BELEZA LTDA
# 9482  22194870/0001  OLYMPIC BROADCASTING SERVICES, S.L - LEI 12.78...
#
#       VALOR DOS INCENTIVOS, RENÚNCIAS, BENEFÍCIOS OU IMUNIDADES DE IPI
# ...

# %%
import pandas as pd

# Supondo que 'df' é o seu DataFrame e 'CNPJ' é a coluna que precisa ser formatada
df_final['CNPJ'] = df_final['CNPJ'].str.replace('[^\w\s]', '')

# Exibindo o DataFrame após a formatação
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6795 entries, 0 to 9482
# Data columns (total 3 columns):
#  #   Column                                                            Non-Null Count  Dtype
# ---  ------                                                            --------------  -----
#  0   CNPJ                                                              6795 non-null   object
#  1   RAZÃO SOCIAL                                                      6795 non-null   object
#  2   VALOR DOS INCENTIVOS, RENÚNCIAS, BENEFÍCIOS OU IMUNIDADES DE IPI  6795 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 212.3+ KB
# <ipython-input-133-b8fc40442e35>:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_final['CNPJ'] = df_final['CNPJ'].str.replace('[^\w\s]', '')

# %%
df_contato_endereço
# Supondo que 'df' é o seu DataFrame e 'CNPJ' é a coluna que precisa ser formatada
df_contato_endereço['CNPJ'] = df_contato_endereço['CNPJ'].str.replace('[^\w\s]', '')

# Exibindo o DataFrame após a formatação
df_contato_endereço
# Out:
# <ipython-input-135-61ae277cd8d6>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_contato_endereço['CNPJ'] = df_contato_endereço['CNPJ'].str.replace('[^\w\s]', '')
#                 CNPJ                                           Endereço  \
# 0    55625511000190   Rua Tapes, 330 Jardim Aeroporto São Paulo / SP...
# 1    18668901000111   ROD JOSE CARLOS DAUX, nº 600, Sala 313 João Pa...
# 2    79647087000143   Rua Joe Colaço, 954 SANTA MONICA Florianópolis...
# 3    06339167000168   Rua Isaias Regis de Miranda, 146V. HAUER HAUER...
# 4    07157915000154    Av. Itabuna, 1880 Centro Ilhéus / BA - 45658565
# ..               ...                                                ...
# 510  30767266000125   RUA GUARANIS, 598 Centro SANTA BARBARA DO OEST...
# 511  81365223000154   BR 282, Km 576 Distrito Industrial Leste Pinha...
# 512  90443821000195   Rua Henrique Eckhardt, 2187 Centro Lajeado / R...
# ...

# %%
merge = pd.merge(df_final, df_contato_endereço, how = 'outer', on = 'CNPJ')
df_merge = merge.fillna("Em branco")
df_merge
# Out:
#                  CNPJ                                       RAZÃO SOCIAL  \
# 0        072054400001                                 AGRICOLA XINGU S/A
# 1        185315940001             SLC-MIT EMPREENDIMENTOS AGRICOLAS S.A.
# 2        890964570001                                  SLC AGRICOLA S.A.
# 3        017229580001  BOA ESPERANCA AGROPECUARIA LTDA - EM RECUPERAC...
# 4        104252820001                           BOM FUTURO AGRICOLA LTDA
# ...               ...                                                ...
# 7305  30767266000125                                           Em branco
# 7306  81365223000154                                           Em branco
# 7307  90443821000195                                           Em branco
# 7308  06105781000165                                           Em branco
# 7309  07019511000102                                           Em branco
#
#      VALOR DOS INCENTIVOS, RENÚNCIAS, BENEFÍCIOS OU IMUNIDADES DE IPI  \
# ...

# %%
# Salvar o DataFrame em um arquivo Excel
df_merge.to_excel('planilha_eriquecida_final_elisa.xlsx', index=False)

# %%
from google.colab import files

# Nome do arquivo que você salvou
nome_do_arquivo = 'planilha_eriquecida_final_elisa.xlsx'

# Baixar o arquivo
files.download(nome_do_arquivo)

# %%
pip install matplotlib

# %%
import matplotlib.pyplot as plt

# Vamos supor que o seu DataFrame seja chamado df_final

# Ordenar o DataFrame pelo valor do IPI em ordem decrescente
df_final_sorted = df_final.sort_values(by='VALOR DOS INCENTIVOS, RENÚNCIAS, BENEFÍCIOS OU IMUNIDADES DE IPI', ascending=False)

# Selecionar as 10 primeiras empresas (ou ajuste conforme necessário)
top_empresas = df_final_sorted.head(10)

# Criar o gráfico de barras
plt.figure(figsize=(10, 6))
plt.barh(top_empresas['RAZÃO SOCIAL'], top_empresas['VALOR DOS INCENTIVOS, RENÚNCIAS, BENEFÍCIOS OU IMUNIDADES DE IPI'], color='skyblue')
plt.xlabel('Valor do IPI')
plt.title('Top 10 Empresas com Maior Valor de IPI')
plt.show()

# %%
pip install seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Vamos supor que o seu DataFrame seja chamado df_final

# Ordenar o DataFrame pelo valor do IPI em ordem decrescente
df_final_sorted = df_final.sort_values(by='VALOR DOS INCENTIVOS, RENÚNCIAS, BENEFÍCIOS OU IMUNIDADES DE IPI', ascending=False)

# Selecionar as 10 primeiras empresas (ou ajuste conforme necessário)
top_empresas = df_final_sorted.head(10)

# Criar o gráfico de barras com seaborn
plt.figure(figsize=(12, 8))
sns.barplot(x='VALOR DOS INCENTIVOS, RENÚNCIAS, BENEFÍCIOS OU IMUNIDADES DE IPI', y='RAZÃO SOCIAL', data=top_empresas, palette='viridis')
plt.xlabel('Valor do IPI')
plt.ylabel('Empresas')
plt.title('Top 10 Empresas com Maior Valor de IPI')
plt.show()
