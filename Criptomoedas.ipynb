# %% [markdown]
# <a href="https://colab.research.google.com/github/ElisaCSouza23/projetos/blob/main/Criptomoedas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

# %% [markdown]
# # Bitcoin
#
#
# fonte: https://br.financas.yahoo.com/quote/BTC-USD/history?p=BTC-USD
#
# Obs: Dados históricos de Janeiro a Dezembro de 2023

# %%
# Carregando o arquivo
bitcoin =  pd.read_csv("/content/BTC-USD_2023.csv")

# %%
# Visualizando o arquivo
bitcoin.head()
# Out:
#          Date          Open          High           Low         Close  \
# 0  2023-01-10  17192.949219  17484.720703  17162.990234  17446.292969
# 1  2023-01-11  17446.359375  17934.896484  17337.994141  17934.896484
# 2  2023-01-12  18117.593750  19030.087891  17995.203125  18869.587891
# 3  2023-01-13  18868.906250  19964.322266  18753.164063  19909.574219
# 4  2023-01-14  19910.537109  21075.142578  19907.828125  20976.298828
#
#       Adj Close       Volume
# 0  17446.292969  15808338949
# 1  17934.896484  18372283782
# 2  18869.587891  34971338710
# 3  19909.574219  29225029694
# 4  20976.298828  38967784639

# %%
# Conferindo o nome das colunas
bitcoin.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
bitcoin['Date'].dtype
# Out:
# dtype('O')

# %%
bitcoin.rename(columns={'Close': 'Close_bitcoin'}, inplace=True)

# %%
bitcoin['Date'] = pd.to_datetime(bitcoin['Date'])

# %%
bitcoin.head()
# Out:
#         Date          Open          High           Low  Close_bitcoin  \
# 0 2023-01-10  17192.949219  17484.720703  17162.990234   17446.292969
# 1 2023-01-11  17446.359375  17934.896484  17337.994141   17934.896484
# 2 2023-01-12  18117.593750  19030.087891  17995.203125   18869.587891
# 3 2023-01-13  18868.906250  19964.322266  18753.164063   19909.574219
# 4 2023-01-14  19910.537109  21075.142578  19907.828125   20976.298828
#
#       Adj Close       Volume
# 0  17446.292969  15808338949
# 1  17934.896484  18372283782
# 2  18869.587891  34971338710
# 3  19909.574219  29225029694
# 4  20976.298828  38967784639

# %%
bitcoin['Date'] = pd.to_datetime(bitcoin['Date'])

# %%
# Configurando o índice como a coluna 'Date'
bitcoin.set_index('Date', inplace=True)

# %%
# Plotando o gráfico interativo
fig = px.line(bitcoin, x=bitcoin.index, y='Close_bitcoin', title='Série Temporal - Fechamento de Preços Bitcoin',
              labels={'Close': 'Preço de Fechamento (USD)', 'index': 'Data'},
              line_shape='linear', render_mode='svg', template='plotly_dark')

# Atualizando o layout com cores desejadas
fig.update_layout({
    'plot_bgcolor': 'black',
    'paper_bgcolor': 'black',
    'font_color': 'white',
    'xaxis': {'gridcolor': 'gray'},
    'yaxis': {'gridcolor': 'gray'},
    'legend': {'font_color': 'white'}
})

# Exibindo o gráfico
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Ethereum
#
# Fonte: https://br.financas.yahoo.com/quote/ETH-USD/history?p=ETH-USD
#
# Obs: Dados históricos de Janeiro a Dezembro de 2023

# %%
# Carregando o arquivo
ethereum =  pd.read_csv("/content/ETH-USD_2023.csv")

# %%
# Visualizando o arquivo
ethereum.head()
# Out:
#          Date         Open         High          Low        Close  \
# 0  2023-01-10  1321.395508  1342.757202  1318.527222  1336.586060
# 1  2023-01-11  1336.486816  1387.932739  1323.583130  1387.932739
# 2  2023-01-12  1405.351440  1432.281250  1378.422119  1417.938477
# 3  2023-01-13  1417.946167  1461.672729  1404.023926  1451.614868
# 4  2023-01-14  1451.428467  1563.739136  1450.988403  1550.706909
#
#      Adj Close       Volume
# 0  1336.586060   5830173253
# 1  1387.932739   6314904311
# 2  1417.938477  12230193038
# 3  1451.614868   7684148212
# 4  1550.706909  15444626014

# %%
# Conferindo o nome das colunas
ethereum.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
ethereum['Date'].dtype
# Out:
# dtype('O')

# %%
ethereum['Date'] = pd.to_datetime(ethereum['Date'])

# %%
ethereum.rename(columns={'Close': 'Close_ethereum'}, inplace=True)

# %%
# Plotando o gráfico interativo
fig = px.line(ethereum, x=ethereum.index, y='Close_ethereum', title='Série Temporal - Fechamento de Preços ethereum',
              labels={'Close': 'Preço de Fechamento (USD)', 'index': 'Data'},
              line_shape='linear', render_mode='svg', template='plotly_dark')

# Atualizando o layout com cores desejadas
fig.update_layout({
    'plot_bgcolor': 'black',
    'paper_bgcolor': 'black',
    'font_color': 'white',
    'xaxis': {'gridcolor': 'gray'},
    'yaxis': {'gridcolor': 'gray'},
    'legend': {'font_color': 'white'}
})

# Exibindo o gráfico
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Litecoin
#
# Fonte: https://br.financas.yahoo.com/quote/LTC-USD/history?p=LTC-USD

# %%
# Carregando o arquivo
litecoin =  pd.read_csv("/content/LTC-USD_2023.csv")

# %%
# Visualizando arquivo
litecoin.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2023-01-10  81.731117  82.596161  79.880600  80.887520  80.887520
# 1  2023-01-11  80.887657  84.414795  80.160622  84.070313  84.070313
# 2  2023-01-12  84.286324  86.039719  82.843849  85.964226  85.964226
# 3  2023-01-13  85.969009  87.583061  83.923912  86.340034  86.340034
# 4  2023-01-14  86.334831  90.645493  86.172760  87.813858  87.813858
#
#        Volume
# 0   561103552
# 1   651624972
# 2   919252860
# 3   726155927
# 4  1235692684

# %%
litecoin['Date'].dtype
# Out:
# dtype('O')

# %%
litecoin['Date'] = pd.to_datetime(litecoin['Date'])

# %%
litecoin.rename(columns={'Close': 'Close_litecoin'}, inplace=True)

# %%
# Plotando o gráfico interativo
fig = px.line(litecoin, x=litecoin.index, y='Close_litecoin', title='Série Temporal - Fechamento de Preços litecoin',
              labels={'Close': 'Preço de Fechamento (USD)', 'index': 'Data'},
              line_shape='linear', render_mode='svg', template='plotly_dark')

# Atualizando o layout com cores desejadas
fig.update_layout({
    'plot_bgcolor': 'black',
    'paper_bgcolor': 'black',
    'font_color': 'white',
    'xaxis': {'gridcolor': 'gray'},
    'yaxis': {'gridcolor': 'gray'},
    'legend': {'font_color': 'white'}
})

# Exibindo o gráfico
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # XRP
#
# Fonte: https://br.financas.yahoo.com/quote/XRP-USD/history?period1=1673308800&period2=1703894400&interval=1d&filter=history&frequency=1d&includeAdjustedClose=true

# %%
# Carregando o arquivo
xrp =  pd.read_csv("/content/XRP-USD.csv")

# %%
# Visualizando arquivo
xrp.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close      Volume
# 0  2023-01-10  0.349325  0.353811  0.345308  0.351241   0.351241   815342810
# 1  2023-01-11  0.351254  0.376026  0.348716  0.374158   0.374158  1498360174
# 2  2023-01-12  0.373827  0.378322  0.365869  0.375197   0.375197  1226464922
# 3  2023-01-13  0.375186  0.386446  0.370640  0.385804   0.385804   990539135
# 4  2023-01-14  0.385807  0.407890  0.385807  0.395443   0.395443  1601102466

# %%
xrp['Date'].dtype
# Out:
# dtype('O')

# %%
xrp['Date'] = pd.to_datetime(xrp['Date'])

# %%
xrp.rename(columns={'Close': 'Close_xrp'}, inplace=True)

# %%
# Plotando o gráfico interativo
fig = px.line(xrp, x=xrp.index, y='Close_xrp', title='Série Temporal - Fechamento de Preços XRP',
              labels={'Close': 'Preço de Fechamento (USD)', 'index': 'Data'},
              line_shape='linear', render_mode='svg', template='plotly_dark')

# Atualizando o layout com cores desejadas
fig.update_layout({
    'plot_bgcolor': 'black',
    'paper_bgcolor': 'black',
    'font_color': 'white',
    'xaxis': {'gridcolor': 'gray'},
    'yaxis': {'gridcolor': 'gray'},
    'legend': {'font_color': 'white'}
})

# Exibindo o gráfico
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('dark_background')  # Define o estilo do fundo como preto


# Resetando o índice para tornar 'Date' uma coluna regular
bitcoin.reset_index(inplace=True)
ethereum.reset_index(inplace=True)
litecoin.reset_index(inplace=True)
xrp.reset_index(inplace=True)

# Selecionando as colunas relevantes
df1_selected = bitcoin[['Date', 'Close_bitcoin']]
df2_selected = ethereum[['Date', 'Close_ethereum']]
df3_selected = litecoin[['Date', 'Close_litecoin']]
df4_selected = xrp[['Date', 'Close_xrp']]

# Realizando os merges
merged_df = pd.merge(df1_selected, df2_selected, on='Date', how='inner')
merged_df = pd.merge(merged_df, df3_selected, on='Date', how='inner')
merged_df = pd.merge(merged_df, df4_selected, on='Date', how='inner')

# Renomeando as colunas para facilitar a plotagem
merged_df.columns = ['Date', 'Bitcoin', 'Ethereum', 'Litecoin', 'XRP']

# Convertendo a coluna 'Date' para o formato datetime
merged_df['Date'] = pd.to_datetime(merged_df['Date'])

# Configurando 'Date' como índice
merged_df.set_index('Date', inplace=True)

# Plotando a série temporal
plt.figure(figsize=(10, 6))
plt.plot(merged_df.index, merged_df['Bitcoin'], label='Bitcoin')
plt.plot(merged_df.index, merged_df['Ethereum'], label='Ethereum')
plt.plot(merged_df.index, merged_df['Litecoin'], label='Litecoin')
plt.plot(merged_df.index, merged_df['XRP'], label='XRP')

plt.title('Série Temporal de Fechamentos')
plt.xlabel('Data')
plt.ylabel('Preço de Fechamento')
plt.legend()
plt.show()

# %%
merged_df
# Out:
#                  Bitcoin     Ethereum   Litecoin       XRP
# Date
# 2023-01-10  17446.292969  1336.586060  80.887520  0.351241
# 2023-01-11  17934.896484  1387.932739  84.070313  0.374158
# 2023-01-12  18869.587891  1417.938477  85.964226  0.375197
# 2023-01-13  19909.574219  1451.614868  86.340034  0.385804
# 2023-01-14  20976.298828  1550.706909  87.813858  0.395443
# ...                  ...          ...        ...       ...
# 2023-12-26  42520.402344  2231.465332  73.150520  0.622369
# 2023-12-27  43442.855469  2378.739990  75.850304  0.634856
# 2023-12-28  42627.855469  2347.566162  76.722328  0.634998
# 2023-12-29  42099.402344  2300.690674  73.404144  0.623402
# 2023-12-30  42156.902344  2292.065430  73.312737  0.621844
#
# [355 rows x 4 columns]

# %%
# Salvar o DataFrame em um arquivo Excel
merged_df.to_csv('cripto.csv', index=False)

from google.colab import files

# Nome do arquivo que você salvou
nome_do_arquivo = 'cripto.csv'

# Baixar o arquivo
files.download(nome_do_arquivo)
